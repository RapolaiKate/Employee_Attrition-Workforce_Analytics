# %% [markdown]
# ##  Data Loading

# %%
import pandas as pd

# %%
import os


os.chdir(r"C:\Users\Kaith\Desktop\Projects\Emplyoyee_Attrition_Dataset_and_Workforce_Analytics\Datasets")

# %%
print(os.getcwd())
print(os.listdir())
# Out:
# C:\Users\Kaith\Desktop\Projects\Emplyoyee_Attrition_Dataset_and_Workforce_Analytics\Datasets
# ['Cleaned_Employee_Attrition.csv', 'Raw_Employee_Attrition.csv']

# %%
df = pd.read_csv("Raw_Employee_Attrition.csv")

# %% [markdown]
# ## Data Inspection

# %%
df.head()
# Out:
#   EmployeeID  Age Department  JobLevel  YearsAtCompany  MonthlyIncome  \
# 0    EMP0000   42      Sales         3               9           9866
# 1    EMP0001   36      Sales         3               7           8958
# 2    EMP0002   44      Sales         4              16          11716
# 3    EMP0003   53    Finance         4              30          17061
# 4    EMP0004   35         HR         2               4           5738
#
#    JobSatisfaction  WorkLifeBalance OverTime  DistanceFromHome  \
# 0                4                1       No              24.5
# 1                3                3       No              10.0
# 2                4                3       No               4.0
# 3                5                3       No               7.1
# 4                2                3       No               8.4
#
#   PromotionLast5Years  PerformanceRating  TrainingHoursLastYear Attrition
# 0                 Yes                  4                     19        No
# ...

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.columns
# Out:
# Index(['EmployeeID', 'Age', 'Department', 'JobLevel', 'YearsAtCompany',
#        'MonthlyIncome', 'JobSatisfaction', 'WorkLifeBalance', 'OverTime',
#        'DistanceFromHome', 'PromotionLast5Years', 'PerformanceRating',
#        'TrainingHoursLastYear', 'Attrition'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   EmployeeID             10000 non-null  str
#  1   Age                    10000 non-null  int64
#  2   Department             10000 non-null  str
#  3   JobLevel               10000 non-null  int64
#  4   YearsAtCompany         10000 non-null  int64
#  5   MonthlyIncome          10000 non-null  int64
#  6   JobSatisfaction        10000 non-null  int64
#  7   WorkLifeBalance        10000 non-null  int64
#  8   OverTime               10000 non-null  str
#  9   DistanceFromHome       10000 non-null  float64
#  10  PromotionLast5Years    10000 non-null  str
#  11  PerformanceRating      10000 non-null  int64
#  12  TrainingHoursLastYear  10000 non-null  int64
#  13  Attrition              10000 non-null  str
# dtypes: float64(1), int64(8), str(5)
# memory usage: 1.1 MB

# %%
df.isnull().sum()
# Out:
# EmployeeID               0
# Age                      0
# Department               0
# JobLevel                 0
# YearsAtCompany           0
# MonthlyIncome            0
# JobSatisfaction          0
# WorkLifeBalance          0
# OverTime                 0
# DistanceFromHome         0
# PromotionLast5Years      0
# PerformanceRating        0
# TrainingHoursLastYear    0
# Attrition                0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#                 Age      JobLevel  YearsAtCompany  MonthlyIncome  \
# count  10000.000000  10000.000000    10000.000000   10000.000000
# mean      37.693500      2.380800        7.788400    8967.918800
# std        9.376457      1.141368        7.141941    3500.745748
# min       22.000000      1.000000        0.000000    3000.000000
# 25%       31.000000      1.000000        2.000000    6043.500000
# 50%       37.000000      2.000000        6.000000    8670.000000
# 75%       44.000000      3.000000       12.000000   11484.000000
# max       60.000000      5.000000       35.000000   21410.000000
#
#        JobSatisfaction  WorkLifeBalance  DistanceFromHome  PerformanceRating  \
# count     10000.000000     10000.000000       10000.00000       10000.000000
# mean          3.362100         2.761500           9.91074           2.603800
# std           1.059951         0.893027           6.97463           0.737889
# ...

# %%
df.describe(include="str")
# Out:
#        EmployeeID Department OverTime PromotionLast5Years Attrition
# count       10000      10000    10000               10000     10000
# unique      10000          7        2                   2         2
# top       EMP0000      Sales       No                  No        No
# freq            1       2453     7151                9086      9097

# %%
df["Attrition"].value_counts()
# Out:
# Attrition
# No     9097
# Yes     903
# Name: count, dtype: int64

# %%
df["Department"].value_counts()
# Out:
# Department
# Sales          2453
# Engineering    2045
# Operations     1513
# Marketing      1188
# Finance        1037
# IT             1035
# HR              729
# Name: count, dtype: int64

# %%
df["JobLevel"].value_counts()
# Out:
# JobLevel
# 1    2844
# 3    2773
# 2    2627
# 4    1389
# 5     367
# Name: count, dtype: int64

# %%
df["YearsAtCompany"].value_counts().sort_index()
# Out:
# YearsAtCompany
# 0     1452
# 1      814
# 2      688
# 3      629
# 4      559
# 5      574
# 6      533
# 7      469
# 8      446
# 9      424
# 10     397
# 11     338
# 12     342
# 13     301
# 14     267
# 15     253
# 16     231
# 17     177
# 18     177
# 19     146
# 20     119
# 21     109
# 22     113
# 23      84
# 24      52
# 25      61
# 26      43
# 27      60
# 28      35
# 29      24
# 30      20
# 31      16
# 32      17
# 33      10
# 34      11
# 35       9
# Name: count, dtype: int64

# %%
df["MonthlyIncome"].describe()
# Out:
# count    10000.000000
# mean      8967.918800
# std       3500.745748
# min       3000.000000
# 25%       6043.500000
# 50%       8670.000000
# 75%      11484.000000
# max      21410.000000
# Name: MonthlyIncome, dtype: float64

# %%
df["JobSatisfaction"].value_counts().sort_index()
# Out:
# JobSatisfaction
# 1     500
# 2    1455
# 3    3476
# 4    3062
# 5    1507
# Name: count, dtype: int64

# %%
df["WorkLifeBalance"].value_counts().sort_index()
# Out:
# WorkLifeBalance
# 1     983
# 2    2515
# 3    4406
# 4    2096
# Name: count, dtype: int64

# %%
df["OverTime"].value_counts()
# Out:
# OverTime
# No     7151
# Yes    2849
# Name: count, dtype: int64

# %%
df["DistanceFromHome"].describe()
# Out:
# count    10000.00000
# mean         9.91074
# std          6.97463
# min          1.00000
# 25%          4.70000
# 50%          8.30000
# 75%         13.40000
# max         50.00000
# Name: DistanceFromHome, dtype: float64

# %%
df["PromotionLast5Years"].value_counts().sort_index()
# Out:
# PromotionLast5Years
# No     9086
# Yes     914
# Name: count, dtype: int64

# %%
df["PerformanceRating"].value_counts().sort_index()
# Out:
# PerformanceRating
# 1     503
# 2    3979
# 3    4495
# 4    1023
# Name: count, dtype: int64

# %%
df["TrainingHoursLastYear"].describe()
# Out:
# count    10000.000000
# mean        14.993100
# std          3.886227
# min          2.000000
# 25%         12.000000
# 50%         15.000000
# 75%         18.000000
# max         31.000000
# Name: TrainingHoursLastYear, dtype: float64

# %%
df["EmployeeID"].nunique()
# Out:
# 10000

# %%
df[[
    "Age", "YearsAtCompany", "MonthlyIncome", "JobSatisfaction", "WorkLifeBalance", "DistanceFromHome", "PromotionLast5Years",
    "PerformanceRating", "TrainingHoursLastYear"]].agg(["min", "max"])
# Out:
#      Age  YearsAtCompany  MonthlyIncome  JobSatisfaction  WorkLifeBalance  \
# min   22               0           3000                1                1
# max   60              35          21410                5                4
#
#      DistanceFromHome PromotionLast5Years  PerformanceRating  \
# min               1.0                  No                  1
# max              50.0                 Yes                  4
#
#      TrainingHoursLastYear
# min                      2
# max                     31

# %%
(df.select_dtypes(include="number") < 0).sum()
# Out:
# Age                      0
# JobLevel                 0
# YearsAtCompany           0
# MonthlyIncome            0
# JobSatisfaction          0
# WorkLifeBalance          0
# DistanceFromHome         0
# PerformanceRating        0
# TrainingHoursLastYear    0
# dtype: int64

# %% [markdown]
# ## Data Inspection
#
# The dataset was inspected to understand its structure, dimensions, data types, summary statistics, missing values, and duplicate records. The dataset contains **10,000 records and 14 columns.** No significant data-quality issues were identified during the inspection.

# %% [markdown]
# ##  Data Cleaning

# %%
import pandas as pd

# %%
import os


os.chdir(r"C:\Users\Kaith\Desktop\Projects\Emplyoyee_Attrition_Dataset_and_Workforce_Analytics\Datasets")

# %%
print(os.getcwd())
print(os.listdir())
# Out:
# C:\Users\Kaith\Desktop\Projects\Emplyoyee_Attrition_Dataset_and_Workforce_Analytics\Datasets
# ['Raw_Employee_Attrition.csv']

# %%
df = pd.read_csv("Raw_Employee_Attrition.csv")

# %%
df.head()
# Out:
#   EmployeeID  Age Department  JobLevel  YearsAtCompany  MonthlyIncome  \
# 0    EMP0000   42      Sales         3               9           9866
# 1    EMP0001   36      Sales         3               7           8958
# 2    EMP0002   44      Sales         4              16          11716
# 3    EMP0003   53    Finance         4              30          17061
# 4    EMP0004   35         HR         2               4           5738
#
#    JobSatisfaction  WorkLifeBalance OverTime  DistanceFromHome  \
# 0                4                1       No              24.5
# 1                3                3       No              10.0
# 2                4                3       No               4.0
# 3                5                3       No               7.1
# 4                2                3       No               8.4
#
#   PromotionLast5Years  PerformanceRating  TrainingHoursLastYear Attrition
# 0                 Yes                  4                     19        No
# ...

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.describe()
# Out:
#                 Age      JobLevel  YearsAtCompany  MonthlyIncome  \
# count  10000.000000  10000.000000    10000.000000   10000.000000
# mean      37.693500      2.380800        7.788400    8967.918800
# std        9.376457      1.141368        7.141941    3500.745748
# min       22.000000      1.000000        0.000000    3000.000000
# 25%       31.000000      1.000000        2.000000    6043.500000
# 50%       37.000000      2.000000        6.000000    8670.000000
# 75%       44.000000      3.000000       12.000000   11484.000000
# max       60.000000      5.000000       35.000000   21410.000000
#
#        JobSatisfaction  WorkLifeBalance  DistanceFromHome  PerformanceRating  \
# count     10000.000000     10000.000000       10000.00000       10000.000000
# mean          3.362100         2.761500           9.91074           2.603800
# std           1.059951         0.893027           6.97463           0.737889
# ...

# %%
df.dtypes
# Out:
# EmployeeID                   str
# Age                        int64
# Department                   str
# JobLevel                   int64
# YearsAtCompany             int64
# MonthlyIncome              int64
# JobSatisfaction            int64
# WorkLifeBalance            int64
# OverTime                     str
# DistanceFromHome         float64
# PromotionLast5Years          str
# PerformanceRating          int64
# TrainingHoursLastYear      int64
# Attrition                    str
# dtype: object

# %%
df["Department"].unique()
# Out:
# <StringArray>
# ['Sales', 'Finance', 'HR', 'IT', 'Engineering', 'Operations', 'Marketing']
# Length: 7, dtype: str

# %%
df["OverTime"].unique()
# Out:
# <StringArray>
# ['No', 'Yes']
# Length: 2, dtype: str

# %%
df["Attrition"].unique()
# Out:
# <StringArray>
# ['No', 'Yes']
# Length: 2, dtype: str

# %%
df["EmployeeID"].head(10)
# Out:
# 0    EMP0000
# 1    EMP0001
# 2    EMP0002
# 3    EMP0003
# 4    EMP0004
# 5    EMP0005
# 6    EMP0006
# 7    EMP0007
# 8    EMP0008
# 9    EMP0009
# Name: EmployeeID, dtype: str

# %%
df["EmployeeID"].duplicated().sum()
# Out:
# np.int64(0)

# %%
df["Age"].min(), df["Age"].max()
# Out:
# (np.int64(22), np.int64(60))

# %%
df["YearsAtCompany"].min(), df["YearsAtCompany"].max()
# Out:
# (np.int64(0), np.int64(35))

# %%
df["MonthlyIncome"].min(), df["MonthlyIncome"].max()
# Out:
# (np.int64(3000), np.int64(21410))

# %%
df["JobSatisfaction"].min(), df["JobSatisfaction"].max()
# Out:
# (np.int64(1), np.int64(5))

# %%
df["WorkLifeBalance"].min(), df["WorkLifeBalance"].max()
# Out:
# (np.int64(1), np.int64(4))

# %%
df["DistanceFromHome"].min(), df["DistanceFromHome"].max()
# Out:
# (np.float64(1.0), np.float64(50.0))

# %%
df["PromotionLast5Years"].min(), df["PromotionLast5Years"].max()
# Out:
# ('No', 'Yes')

# %%
df["PerformanceRating"].min(), df["PerformanceRating"].max()
# Out:
# (np.int64(1), np.int64(4))

# %%
df["TrainingHoursLastYear"].min(), df["TrainingHoursLastYear"].max()
# Out:
# (np.int64(2), np.int64(31))

# %%
df["Department"].str.strip().ne(df["Department"]).sum()
# Out:
# np.int64(0)

# %%
df["OverTime"].str.strip().ne(df["OverTime"]).sum()
# Out:
# np.int64(0)

# %%
df["Attrition"].str.strip().ne(df["Attrition"]).sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df_clean = df.copy()

# %%
df_clean.head()
# Out:
#   EmployeeID  Age Department  JobLevel  YearsAtCompany  MonthlyIncome  \
# 0    EMP0000   42      Sales         3               9           9866
# 1    EMP0001   36      Sales         3               7           8958
# 2    EMP0002   44      Sales         4              16          11716
# 3    EMP0003   53    Finance         4              30          17061
# 4    EMP0004   35         HR         2               4           5738
#
#    JobSatisfaction  WorkLifeBalance OverTime  DistanceFromHome  \
# 0                4                1       No              24.5
# 1                3                3       No              10.0
# 2                4                3       No               4.0
# 3                5                3       No               7.1
# 4                2                3       No               8.4
#
#   PromotionLast5Years  PerformanceRating  TrainingHoursLastYear Attrition
# 0                 Yes                  4                     19        No
# ...

# %%
df_clean = df.copy()
df_clean.shape
df_clean.head()
# Out:
#   EmployeeID  Age Department  JobLevel  YearsAtCompany  MonthlyIncome  \
# 0    EMP0000   42      Sales         3               9           9866
# 1    EMP0001   36      Sales         3               7           8958
# 2    EMP0002   44      Sales         4              16          11716
# 3    EMP0003   53    Finance         4              30          17061
# 4    EMP0004   35         HR         2               4           5738
#
#    JobSatisfaction  WorkLifeBalance OverTime  DistanceFromHome  \
# 0                4                1       No              24.5
# 1                3                3       No              10.0
# 2                4                3       No               4.0
# 3                5                3       No               7.1
# 4                2                3       No               8.4
#
#   PromotionLast5Years  PerformanceRating  TrainingHoursLastYear Attrition
# 0                 Yes                  4                     19        No
# ...

# %%
df_clean["Age"].plot(kind="hist", bins=10)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.to_csv("Employee_Attrition_Final_Dataset.csv")

# %%
print(os.path.exists("Employee_Attrition_Final_Dataset.csv"))
# Out:
# True

# %% [markdown]
# ## Data Cleaning
#
# The dataset was reviewed for missing values, duplicate records, inconsistent data types, and potential data-quality issues. No significant issues were identified, so no major transformations were required. The dataset was validated and prepared for exploratory data analysis.

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
df_clean["Age"].describe()
# Out:
# count    10000.000000
# mean        37.693500
# std          9.376457
# min         22.000000
# 25%         31.000000
# 50%         37.000000
# 75%         44.000000
# max         60.000000
# Name: Age, dtype: float64

# %%
df_clean["Department"].value_counts()
# Out:
# Department
# Sales          2453
# Engineering    2045
# Operations     1513
# Marketing      1188
# Finance        1037
# IT             1035
# HR              729
# Name: count, dtype: int64

# %%
df_clean["JobLevel"].value_counts().sort_index()
# Out:
# JobLevel
# 1    2844
# 2    2627
# 3    2773
# 4    1389
# 5     367
# Name: count, dtype: int64

# %%
df_clean["YearsAtCompany"].describe()
# Out:
# count    10000.000000
# mean         7.788400
# std          7.141941
# min          0.000000
# 25%          2.000000
# 50%          6.000000
# 75%         12.000000
# max         35.000000
# Name: YearsAtCompany, dtype: float64

# %%
df_clean["MonthlyIncome"].describe()
# Out:
# count    10000.000000
# mean      8967.918800
# std       3500.745748
# min       3000.000000
# 25%       6043.500000
# 50%       8670.000000
# 75%      11484.000000
# max      21410.000000
# Name: MonthlyIncome, dtype: float64

# %%
df_clean["JobSatisfaction"].value_counts().sort_index()
# Out:
# JobSatisfaction
# 1     500
# 2    1455
# 3    3476
# 4    3062
# 5    1507
# Name: count, dtype: int64

# %%
df_clean["WorkLifeBalance"].value_counts().sort_index()
# Out:
# WorkLifeBalance
# 1     983
# 2    2515
# 3    4406
# 4    2096
# Name: count, dtype: int64

# %%
df_clean["DistanceFromHome"].describe()
# Out:
# count    10000.00000
# mean         9.91074
# std          6.97463
# min          1.00000
# 25%          4.70000
# 50%          8.30000
# 75%         13.40000
# max         50.00000
# Name: DistanceFromHome, dtype: float64

# %%
df_clean["TrainingHoursLastYear"].describe()
# Out:
# count    10000.000000
# mean        14.993100
# std          3.886227
# min          2.000000
# 25%         12.000000
# 50%         15.000000
# 75%         18.000000
# max         31.000000
# Name: TrainingHoursLastYear, dtype: float64

# %%
df_clean["PerformanceRating"].value_counts().sort_index()
# Out:
# PerformanceRating
# 1     503
# 2    3979
# 3    4495
# 4    1023
# Name: count, dtype: int64

# %%
df_clean["Attrition"].value_counts().sort_index()
# Out:
# Attrition
# No     9097
# Yes     903
# Name: count, dtype: int64

# %%
df["Attrition"].value_counts(normalize=True) * 100
# Out:
# Attrition
# No     90.97
# Yes     9.03
# Name: proportion, dtype: float64

# %%
pd.crosstab(df_clean["Department"], df_clean["Attrition"])
# Out:
# Attrition      No  Yes
# Department
# Engineering  1849  196
# Finance       952   85
# HR            676   53
# IT            942   93
# Marketing    1080  108
# Operations   1378  135
# Sales        2220  233

# %% [raw]
# pd.crootab(df_clean["OverTime"], df_clean["Attrition"])

# %%
pd.crosstab(df_clean["JobLevel"], df_clean["Attrition"])
# Out:
# Attrition    No  Yes
# JobLevel
# 1          2525  319
# 2          2386  241
# 3          2519  254
# 4          1319   70
# 5           348   19

# %%
pd.crosstab(df_clean["WorkLifeBalance"], df_clean["Attrition"])
# Out:
# Attrition          No  Yes
# WorkLifeBalance
# 1                 864  119
# 2                2210  305
# 3                4071  335
# 4                1952  144

# %%
pd.crosstab(df_clean["PromotionLast5Years"], df_clean["Attrition"])
# Out:
# Attrition              No  Yes
# PromotionLast5Years
# No                   8244  842
# Yes                   853   61

# %%
pd.crosstab(df_clean["PerformanceRating"], df_clean["Attrition"])
# Out:
# Attrition            No  Yes
# PerformanceRating
# 1                   447   56
# 2                  3574  405
# 3                  4143  352
# 4                   933   90

# %%
df_clean.groupby("Attrition")["YearsAtCompany"].describe()
# Out:
#             count      mean       std  min  25%  50%   75%   max
# Attrition
# No         9097.0  7.917555  7.177301  0.0  2.0  6.0  12.0  35.0
# Yes         903.0  6.487265  6.640399  0.0  1.0  5.0  10.0  35.0

# %%
df_clean.groupby("Attrition")["Age"].describe()
# Out:
#             count       mean       std   min   25%   50%   75%   max
# Attrition
# No         9097.0  37.807959  9.375037  22.0  31.0  38.0  44.0  60.0
# Yes         903.0  36.540421  9.317763  22.0  30.0  36.0  43.0  60.0

# %%
df_clean.groupby("Attrition")["MonthlyIncome"].describe()
# Out:
#             count         mean          std     min     25%     50%      75%  \
# Attrition
# No         9097.0  9032.829944  3517.748847  3000.0  6089.0  8750.0  11570.0
# Yes         903.0  8313.991141  3254.965639  3052.0  5678.0  7925.0  10467.0
#
#                max
# Attrition
# No         21410.0
# Yes        19023.0

# %%
df_clean.groupby("Attrition")["DistanceFromHome"].describe()
# Out:
#             count      mean       std  min  25%  50%    75%   max
# Attrition
# No         9097.0  9.913851  6.970865  1.0  4.7  8.3  13.40  50.0
# Yes         903.0  9.879402  7.016254  1.0  5.0  8.2  13.25  50.0

# %%
df_clean.groupby("Attrition")["TrainingHoursLastYear"].describe()
# Out:
#             count       mean       std  min   25%   50%   75%   max
# Attrition
# No         9097.0  15.000440  3.878770  2.0  12.0  15.0  18.0  30.0
# Yes         903.0  14.919158  3.962001  5.0  12.0  15.0  17.5  31.0

# %%
pd.crosstab([df_clean["Department"], df_clean["OverTime"]], df_clean["Attrition"])
# Out:
# Attrition               No  Yes
# Department  OverTime
# Engineering No        1180  110
#             Yes        669   86
# Finance     No         782   63
#             Yes        170   22
# HR          No         527   39
#             Yes        149   14
# IT          No         634   56
#             Yes        308   37
# Marketing   No         874   78
#             Yes        206   30
# Operations  No        1125   89
#             Yes        253   46
# Sales       No        1473  121
#             Yes        747  112

# %%
df_clean["Attrition"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Attrition'>

# %%
pd.crosstab(df_clean["Department"], df_clean["Attrition"]).plot(kind="bar")
# Out:
# <Axes: xlabel='Department'>

# %%
pd.crosstab(df_clean["OverTime"], df_clean["Attrition"]).plot(kind="bar")
# Out:
# <Axes: xlabel='OverTime'>

# %%
pd.crosstab(df_clean["JobLevel"], df_clean["Attrition"]).plot(kind="bar")
# Out:
# <Axes: xlabel='JobLevel'>

# %%
pd.crosstab(df_clean["JobSatisfaction"], df_clean["Attrition"]).plot(kind="bar")
# Out:
# <Axes: xlabel='JobSatisfaction'>

# %%
df_clean["Attrition"].value_counts(normalize=True) * 100
# Out:
# Attrition
# No     90.97
# Yes     9.03
# Name: proportion, dtype: float64

# %%
pd.crosstab( df_clean["Department"], df_clean["Attrition"], normalize="index") * 100
# Out:
# Attrition           No       Yes
# Department
# Engineering  90.415648  9.584352
# Finance      91.803279  8.196721
# HR           92.729767  7.270233
# IT           91.014493  8.985507
# Marketing    90.909091  9.090909
# Operations   91.077330  8.922670
# Sales        90.501427  9.498573

# %%
pd.crosstab( df_clean["OverTime"], df_clean["Attrition"], normalize="index") * 100
# Out:
# Attrition         No        Yes
# OverTime
# No         92.224864   7.775136
# Yes        87.820288  12.179712

# %%
pd.crosstab( df_clean["JobSatisfaction"], df_clean["Attrition"], normalize="index") * 100
# Out:
# Attrition               No        Yes
# JobSatisfaction
# 1                86.400000  13.600000
# 2                83.367698  16.632302
# 3                92.548907   7.451093
# 4                92.619203   7.380797
# 5                92.833444   7.166556

# %%
pd.crosstab( df_clean["JobLevel"], df_clean["Attrition"], normalize="index") * 100
# Out:
# Attrition         No        Yes
# JobLevel
# 1          88.783404  11.216596
# 2          90.826037   9.173963
# 3          90.840245   9.159755
# 4          94.960403   5.039597
# 5          94.822888   5.177112

# %%
pd.crosstab( df_clean["WorkLifeBalance"], df_clean["Attrition"], normalize="index") * 100
# Out:
# Attrition               No        Yes
# WorkLifeBalance
# 1                87.894201  12.105799
# 2                87.872763  12.127237
# 3                92.396732   7.603268
# 4                93.129771   6.870229

# %%
pd.crosstab( df_clean["PromotionLast5Years"], df_clean["Attrition"], normalize="index") * 100
# Out:
# Attrition                   No       Yes
# PromotionLast5Years
# No                   90.732996  9.267004
# Yes                  93.326039  6.673961

# %%
pd.crosstab( df_clean["PerformanceRating"], df_clean["Attrition"], normalize="index") * 100
# Out:
# Attrition                 No        Yes
# PerformanceRating
# 1                  88.866799  11.133201
# 2                  89.821563  10.178437
# 3                  92.169077   7.830923
# 4                  91.202346   8.797654

# %%
pd.crosstab( df_clean["Department"], df_clean["Attrition"], normalize="index").plot(kind="bar")
# Out:
# <Axes: xlabel='Department'>

# %%
pd.crosstab( df_clean["OverTime"], df_clean["Attrition"], normalize="index").plot(kind="bar")
# Out:
# <Axes: xlabel='OverTime'>

# %%
pd.crosstab( df_clean["JobLevel"], df_clean["Attrition"], normalize="index").plot(kind="bar")
# Out:
# <Axes: xlabel='JobLevel'>

# %%
pd.crosstab( df_clean["WorkLifeBalance"], df_clean["Attrition"], normalize="index").plot(kind="bar")
# Out:
# <Axes: xlabel='WorkLifeBalance'>

# %%
df_clean.boxplot(column="Age", by="Attrition")
# Out:
# <Axes: title={'center': 'Age'}, xlabel='Attrition'>

# %%
df_clean.boxplot(column="MonthlyIncome", by="Attrition")
# Out:
# <Axes: title={'center': 'MonthlyIncome'}, xlabel='Attrition'>

# %%
df_clean.boxplot(column="YearsAtCompany", by="Attrition")
# Out:
# <Axes: title={'center': 'YearsAtCompany'}, xlabel='Attrition'>

# %%
df_clean.boxplot(column="DistanceFromHome", by="Attrition")
# Out:
# <Axes: title={'center': 'DistanceFromHome'}, xlabel='Attrition'>

# %%
df_clean.boxplot(column="TrainingHoursLastYear", by="Attrition")
# Out:
# <Axes: title={'center': 'TrainingHoursLastYear'}, xlabel='Attrition'>

# %%
pd.crosstab( df_clean["JobLevel"], df_clean["Attrition"], normalize="index") ["Yes"].sort_values(ascending=False) * 100
# Out:
# JobLevel
# 1    11.216596
# 2     9.173963
# 3     9.159755
# 5     5.177112
# 4     5.039597
# Name: Yes, dtype: float64

# %%
df_clean.groupby("Attrition") ["TrainingHoursLastYear"].mean()
# Out:
# Attrition
# No     15.000440
# Yes    14.919158
# Name: TrainingHoursLastYear, dtype: float64

# %%
df_clean.to_csv("Employee_attrition_cleaned.csv", index=False)

# %%
df_clean.shape

# %% [markdown]
# ## EDA Finding
#
# The exploratory analysis examined employee attrition across departments, job levels, overtime, job satisfaction, work-life balance, years at company, performance ratings, and promotion history. The analysis identified patterns and factors associated with employee attrition, providing usefull insights for workforce planning and employee retention.
